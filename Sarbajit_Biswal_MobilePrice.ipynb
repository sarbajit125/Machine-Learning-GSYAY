# %% [markdown]
# <a href="https://colab.research.google.com/github/sarbajit125/Machine-Learning-GSYAY/blob/main/Sarbajit_Biswal_MobilePrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Mobile+phone+-+Hemanka+Sarma.csv')
data.head(5)
np.isnan(data.values).any()
# No mission values
# Out:
# False

# %%
#EDA
data.shape
# Out:
# (2000, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data.price_range.unique()
# Out:
# array([1, 2, 3, 0])

# %%
data.price_range.value_counts()
# Out:
# 0    500
# 1    500
# 2    500
# 3    500
# Name: price_range, dtype: int64

# %%
# Some plots with respect to interesting facts

classes = ['battery_power','clock_speed','n_cores','ram','three_g','four_g','touch_screen']

# %%
import seaborn as sns

# %%
sns.countplot(data['price_range'])
# Out:
# /home/sanket/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='count'>

# %%
data[classes].hist(bins=15, figsize=(15, 6), layout=(2, 4))
# Out:
# array([[<AxesSubplot:title={'center':'battery_power'}>,
#         <AxesSubplot:title={'center':'clock_speed'}>,
#         <AxesSubplot:title={'center':'n_cores'}>,
#         <AxesSubplot:title={'center':'ram'}>],
#        [<AxesSubplot:title={'center':'three_g'}>,
#         <AxesSubplot:title={'center':'four_g'}>,
#         <AxesSubplot:title={'center':'touch_screen'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 10))
for variable, subplot in zip(classes, ax.flatten()):
    sns.countplot(data[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)
# Out:
# /home/sanket/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sanket/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sanket/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Model

# %%
X = data.iloc[:,:-1].values
Y= data['price_range']

# %%
X =X[:,1:]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test =sc_X.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train,Y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[95 10  0  0]
#  [11 65 15  0]
#  [ 0 11 70 11]
#  [ 0  0 16 96]]

# %% [markdown]
# ### R2 Score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test,y_pred)
print(r2)
# Out:
# 0.8613446755886995

# %% [markdown]
# ### Making the prediction with KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier1 = KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier1.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1 = classifier1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred1)
print(cm)
# Out:
# [[72 26  7  0]
#  [33 34 19  5]
#  [11 34 37 10]
#  [ 0 14 40 58]]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test,y_pred1)
print(r2)
# Out:
# 0.4191466139526604

# %% [markdown]
# ### Hence Logistic Regreesion gave a better result so far compared to KNN algo
